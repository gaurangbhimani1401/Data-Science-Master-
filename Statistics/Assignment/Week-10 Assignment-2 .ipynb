# %% [markdown]
# Q1. What are the three measures of central tendency?

# %%
Ans 1:-
Mean:
    The mean is the arithmetic average of a set of values.
    It is calculated by summing up all the values in the dataset and dividing by the total number of values.

Median:
    The median is the middle value in a dataset when it is arranged in ascending or descending order.
    If the dataset has an odd number of values, the median is the middle value.
    If the dataset has an even number of values, the median is the average of the two middle values.

Mode:
    The mode is the value or values that appear most frequently in a dataset.
    It represents the most common value(s) in the dataset.

# %% [markdown]
# Q2. What is the difference between the mean, median, and mode? How are they used to measure the
# central tendency of a dataset?

# %%
Ans 2:-
Mean:
    The mean is the average value of a dataset.
    It is calculated by summing up all the values in the dataset and dividing by the total number of values.
    The mean takes into account every value in the dataset and is sensitive to outliers.
    It is commonly used when the dataset follows a normal distribution or when there are no extreme values.

Median:
    The median is the middle value of a dataset when it is arranged in ascending or descending order.
    If the dataset has an odd number of values, the median is the middle value.
    If the dataset has an even number of values, the median is the average of the two middle values.
    The median is not influenced by extreme values or outliers and is a robust measure of central tendency.
    It is commonly used when the dataset has skewed distribution or contains outliers.

Mode:
    The mode is the value or values that appear most frequently in a dataset.
    It represents the most common value(s) in the dataset.
    Unlike the mean and median, the mode does not consider the actual values of the dataset, only their frequencies.
    The mode is used to identify the most prevalent category or value in a dataset.

# %% [markdown]
# Q3. Measure the three measures of central tendency for the given height data:
# [178,177,176,177,178.2,178,175,179,180,175,178.9,176.2,177,172.5,178,176.5]

# %%
# Ans 3:-
import numpy as np
import statistics as sts
height = [178,177,176,177,178.2,178,175,179,180,175,178.9,176.2,177,172.5,178,176.5]

# %%
np.mean(height)
# Out:
# 177.01875

# %%
np.median(height)
# Out:
# 177.0

# %%
sts.mode(height)
# Out:
# 178

# %% [markdown]
# Q4. Find the standard deviation for the given data:
# [178,177,176,177,178.2,178,175,179,180,175,178.9,176.2,177,172.5,178,176.5]

# %%
# Ans 4:-
import numpy as np
import statistics as sts
data = [178,177,176,177,178.2,178,175,179,180,175,178.9,176.2,177,172.5,178,176.5]

# %%
sts.stdev(data)
# Out:
# 1.8472389305844188

# %% [markdown]
# Q5. How are measures of dispersion such as range, variance, and standard deviation used to describe
# the spread of a dataset? Provide an example.

# %%
Ans 5:-
Range:
    The range is the simplest measure of dispersion and is calculated as the difference between the maximum and minimum values in a dataset.
    It gives an idea of the overall spread of the data.

Variance:
    Variance measures the average squared deviation from the mean.
    It quantifies the dispersion of data points around the mean.
    A higher variance indicates a greater spread of data points.

Standard Deviation:
    The standard deviation is the square root of the variance.
    It provides a measure of the average distance between each data point and the mean.
    A higher standard deviation indicates a greater dispersion of data points.

# %%
import numpy as np
data = [178, 177, 176, 177, 178.2, 178, 175, 179, 180, 175, 178.9, 176.2, 177, 172.5, 178, 176.5]
data_range = np.max(data) - np.min(data)
data_variance = np.var(data)
data_std = np.std(data)

print("Range:", data_range)
print("Variance:", data_variance)
print("Standard Deviation:", data_std)
# Out:
# Range: 7.5
# Variance: 3.199023437500001
# Standard Deviation: 1.7885814036548633

# %% [markdown]
# Q6. What is a Venn diagram?

# %%
Ans 6:-
A Venn diagram is a visual representation of the relationships between different sets of data or groups.
It consists of overlapping circles or ellipses, where each circle represents a set or a group, and the overlapping regions represent the elements that are
common to multiple sets.

# %% [markdown]
# Q7. For the two given sets A = (2,3,4,5,6,7) & B = (0,2,6,8,10). Find:
# (i) A B
# (ii) A ⋃ B

# %%
# Ans 7:-
A = {2, 3, 4, 5, 6, 7}
B = {0, 2, 6, 8, 10}

# %%
A.intersection(B)
# Out:
# {2, 6}

# %%
A.union(B)
# Out:
# {0, 2, 3, 4, 5, 6, 7, 8, 10}

# %% [markdown]
# Q8. What do you understand about skewness in data?

# %%
Ans 8:-
Skewness is a statistical measure that describes the asymmetry or lack of symmetry in a distribution of data.
It provides information about the shape of the distribution. A distribution can be classified as positively skewed (right-skewed), negatively skewed
(left-skewed), or symmetric (no skewness).

# %% [markdown]
# Q9. If a data is right skewed then what will be the position of median with respect to mean?

# %%
Ans 9:-
In a right-skewed distribution, the median will typically be lower than the mean.
This is because the right-skewed distribution is characterized by a long tail on the right side, which is comprised of relatively larger values.
As a result, these larger values pull the mean towards the right, making it greater than the median.

# %% [markdown]
# Q10. Explain the difference between covariance and correlation. How are these measures used in
# statistical analysis?

# %%
Ans 10:-
Covariance measures the direction and strength of the linear relationship between two variables.
It indicates how changes in one variable are associated with changes in the other variable. 
A positive covariance indicates a positive relationship, meaning that as one variable increases, the other tends to increase as well.

# %%
Correlation, on the other hand, standardizes the covariance by dividing it by the product of the standard deviations of the variables.
This results in a correlation coefficient that ranges from -1 to 1.
A correlation coefficient of 1 indicates a perfect positive correlation, -1 indicates a perfect negative correlation, and 0 indicates no correlation.

# %% [markdown]
# Q11. What is the formula for calculating the sample mean? Provide an example calculation for a
# dataset.

# %%
Ans 11:-
The formula for calculating the sample mean, denoted as x̄ (pronounced "x-bar"), is:

x̄ = (x₁ + x₂ + x₃ + ... + xn) / n

x₁, x₂, x₃, ..., xn are the individual values in the dataset,
n is the number of values in the dataset.

Dataset: [5, 7, 9, 3, 6]

x̄ = (5 + 7 + 9 + 3 + 6) / 5
= 30 / 5
= 6

# %% [markdown]
# Q12. For a normal distribution data what is the relationship between its measure of central tendency?

# %%
Ans 12:-
In a normal distribution, the measure of central tendency, which includes the mean, median, and mode, are all equal and located at the center of the distribution.

# %%
The mean, denoted as μ (mu), is located at the center of the normal distribution.
The median is also located at the center of the distribution, which is the same as the mean.
The mode, representing the most frequently occurring value, is also equal to the mean and median in a symmetric normal distribution.

# %% [markdown]
# Q13. How is covariance different from correlation?

# %%
Ans 13:-
Covariance measures the direction and strength of the linear relationship between two variables.
It indicates how changes in one variable are associated with changes in the other variable.
The covariance can be positive, negative, or zero.
A positive covariance indicates a positive relationship, a negative covariance indicates a negative relationship, and a covariance of zero indicates
no linear relationship.

# %%
Correlation, on the other hand, is a standardized measure of the linear relationship between two variables.
It is calculated by dividing the covariance by the product of the standard deviations of the two variables.
Correlation values range from -1 to +1, where -1 indicates a perfect negative correlation, +1 indicates a perfect positive correlation,
and 0 indicates no linear correlation.

# %% [markdown]
# Q14. How do outliers affect measures of central tendency and dispersion? Provide an example.

# %%
Ans 14:-
Measures of central tendency, such as the mean and median, can be greatly influenced by outliers.
Outliers that are significantly higher or lower than the other data points can pull the mean towards them, causing it to be unrepresentative of the
majority of the data.

# %%
import numpy as np
import statistics as sts
Dataset1= [10, 20, 30, 40, 50]
Dataset2= [10, 20, 30, 40, 50, 100]

# %%
np.mean(Dataset1)
# Out:
# 30.0

# %%
np.mean(Dataset2)
# Out:
# 41.666666666666664

# %%
sts.stdev(Dataset1)
# Out:
# 15.811388300841896

# %%
sts.stdev(Dataset2)
# Out:
# 31.88521078284832
