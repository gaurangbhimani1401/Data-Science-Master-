# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.linspace(0,10 ,300)

# %%
x
# Out:
# array([ 0.        ,  0.03344482,  0.06688963,  0.10033445,  0.13377926,
#         0.16722408,  0.2006689 ,  0.23411371,  0.26755853,  0.30100334,
#         0.33444816,  0.36789298,  0.40133779,  0.43478261,  0.46822742,
#         0.50167224,  0.53511706,  0.56856187,  0.60200669,  0.63545151,
#         0.66889632,  0.70234114,  0.73578595,  0.76923077,  0.80267559,
#         0.8361204 ,  0.86956522,  0.90301003,  0.93645485,  0.96989967,
#         1.00334448,  1.0367893 ,  1.07023411,  1.10367893,  1.13712375,
#         1.17056856,  1.20401338,  1.23745819,  1.27090301,  1.30434783,
#         1.33779264,  1.37123746,  1.40468227,  1.43812709,  1.47157191,
#         1.50501672,  1.53846154,  1.57190635,  1.60535117,  1.63879599,
#         1.6722408 ,  1.70568562,  1.73913043,  1.77257525,  1.80602007,
#         1.83946488,  1.8729097 ,  1.90635452,  1.93979933,  1.97324415,
#         2.00668896,  2.04013378,  2.0735786 ,  2.10702341,  2.14046823,
# ...

# %%
y = np.sin(x)

# %%
y
# Out:
# array([ 0.        ,  0.03343858,  0.06683976,  0.10016619,  0.13338058,
#         0.1664458 ,  0.19932485,  0.23198097,  0.26437762,  0.29647859,
#         0.32824796,  0.3596502 ,  0.39065018,  0.42121325,  0.4513052 ,
#         0.4808924 ,  0.50994174,  0.53842073,  0.56629753,  0.59354095,
#         0.62012052,  0.64600652,  0.67116999,  0.69558279,  0.71921762,
#         0.74204803,  0.76404851,  0.78519443,  0.80546214,  0.82482899,
#         0.84327331,  0.86077446,  0.87731288,  0.89287007,  0.90742863,
#         0.92097227,  0.93348585,  0.94495538,  0.95536801,  0.96471211,
#         0.97297723,  0.98015412,  0.98623476,  0.99121234,  0.99508129,
#         0.9978373 ,  0.99947728,  0.99999938,  0.99940304,  0.99768891,
#         0.99485892,  0.99091623,  0.98586524,  0.97971161,  0.97246222,
#         0.96412518,  0.95470981,  0.94422665,  0.93268741,  0.92010501,
#         0.90649351,  0.89186815,  0.87624528,  0.85964236,  0.84207798,
# ...

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xlabel("this is my X data")
plt.ylabel("this is the y data")
plt.title("this is the graph title")
plt.show()

# %%
colours = np.random.rand(50)
size = 200*np.random.rand(50)
x = np.random.rand(50)
y = np.random.rand(50)
plt.xlabel("X data")
plt.ylabel("y data")
plt.title("graph title")
plt.scatter(x,y,c = colours,s = size,alpha=.7)

# %%
x
# Out:
# array([0.77135409, 0.25411564, 0.31407649, 0.97494109, 0.65673926,
#        0.75657984, 0.35899295, 0.1859296 , 0.0070511 , 0.1621906 ,
#        0.51406289, 0.10041739, 0.26447369, 0.97080668, 0.58004618,
#        0.94859627, 0.54214838, 0.24425156, 0.79537755, 0.76784548,
#        0.02089447, 0.27905481, 0.54217586, 0.05174589, 0.66868221,
#        0.78730794, 0.18678839, 0.40256156, 0.03401829, 0.52560553,
#        0.41571568, 0.8124169 , 0.82218493, 0.46166534, 0.8168189 ,
#        0.46050229, 0.80673288, 0.04708816, 0.59765648, 0.52789296,
#        0.65712493, 0.0079096 , 0.25548332, 0.07016611, 0.6118334 ,
#        0.83366884, 0.16735939, 0.35654619, 0.78089657, 0.08951753])

# %%
y
# Out:
# array([0.10012717, 0.95961789, 0.27637456, 0.90487312, 0.15459543,
#        0.31469073, 0.7278959 , 0.697303  , 0.01501382, 0.73505339,
#        0.38742172, 0.25944471, 0.45138348, 0.4987371 , 0.43870832,
#        0.17510004, 0.36925526, 0.75527591, 0.65005591, 0.37375116,
#        0.51080205, 0.67546547, 0.70530113, 0.1213782 , 0.3054883 ,
#        0.94583895, 0.17953755, 0.22367618, 0.88201529, 0.0743051 ,
#        0.01806647, 0.11261771, 0.74224415, 0.18931786, 0.60856691,
#        0.94877863, 0.6061289 , 0.34005547, 0.24716678, 0.3487116 ,
#        0.69205467, 0.13591288, 0.40313263, 0.27309689, 0.62518963,
#        0.42482579, 0.23306946, 0.08859945, 0.02533884, 0.62845257])

# %%
x = ['a','b','c','d','e']

# %%
y = np.random.rand(5)

# %%
plt.bar(x,y)
plt.xlabel("X data")
plt.ylabel("y data")
plt.title("bar graph title")
# Out:
# Text(0.5, 1.0, 'bar graph title')

# %%
y
# Out:
# array([0.05541476, 0.09390462, 0.34779304, 0.1644726 , 0.49693551])

# %%
plt.barh(x,y)
plt.xlabel("X data")
plt.ylabel("y data")
plt.title("bar graph title")
# Out:
# Text(0.5, 1.0, 'bar graph title')

# %%
x = np.linspace(0,10 ,300)
y = np.sin(x)

# %%
x
# Out:
# array([ 0.        ,  0.03344482,  0.06688963,  0.10033445,  0.13377926,
#         0.16722408,  0.2006689 ,  0.23411371,  0.26755853,  0.30100334,
#         0.33444816,  0.36789298,  0.40133779,  0.43478261,  0.46822742,
#         0.50167224,  0.53511706,  0.56856187,  0.60200669,  0.63545151,
#         0.66889632,  0.70234114,  0.73578595,  0.76923077,  0.80267559,
#         0.8361204 ,  0.86956522,  0.90301003,  0.93645485,  0.96989967,
#         1.00334448,  1.0367893 ,  1.07023411,  1.10367893,  1.13712375,
#         1.17056856,  1.20401338,  1.23745819,  1.27090301,  1.30434783,
#         1.33779264,  1.37123746,  1.40468227,  1.43812709,  1.47157191,
#         1.50501672,  1.53846154,  1.57190635,  1.60535117,  1.63879599,
#         1.6722408 ,  1.70568562,  1.73913043,  1.77257525,  1.80602007,
#         1.83946488,  1.8729097 ,  1.90635452,  1.93979933,  1.97324415,
#         2.00668896,  2.04013378,  2.0735786 ,  2.10702341,  2.14046823,
# ...

# %%
y
# Out:
# array([ 0.        ,  0.03343858,  0.06683976,  0.10016619,  0.13338058,
#         0.1664458 ,  0.19932485,  0.23198097,  0.26437762,  0.29647859,
#         0.32824796,  0.3596502 ,  0.39065018,  0.42121325,  0.4513052 ,
#         0.4808924 ,  0.50994174,  0.53842073,  0.56629753,  0.59354095,
#         0.62012052,  0.64600652,  0.67116999,  0.69558279,  0.71921762,
#         0.74204803,  0.76404851,  0.78519443,  0.80546214,  0.82482899,
#         0.84327331,  0.86077446,  0.87731288,  0.89287007,  0.90742863,
#         0.92097227,  0.93348585,  0.94495538,  0.95536801,  0.96471211,
#         0.97297723,  0.98015412,  0.98623476,  0.99121234,  0.99508129,
#         0.9978373 ,  0.99947728,  0.99999938,  0.99940304,  0.99768891,
#         0.99485892,  0.99091623,  0.98586524,  0.97971161,  0.97246222,
#         0.96412518,  0.95470981,  0.94422665,  0.93268741,  0.92010501,
#         0.90649351,  0.89186815,  0.87624528,  0.85964236,  0.84207798,
# ...

# %%
plt.figure(figsize=(6,2))
plt.plot(x,y,'--r')
plt.xlabel("X data")
plt.ylabel("y data")
plt.title("bar graph title")
plt.grid()
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
colours = np.random.rand(50)
size = 200*np.random.rand(50)
x = np.random.rand(50)
y = np.random.rand(50)
plt.xlabel("X data")
plt.ylabel("y data")
plt.title("graph title")
plt.scatter(x,y,c = 'b',s = size,alpha=.7,marker = 'x')

# %%
x = [4,5,6,7,8,9]
y = [1,2,3,4,34,23]
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = [4,5,6,7,8,9]
y = [1,2,3,4,34,23]
plt.scatter(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data = [1,4,2,4,5,6,7,5,3,3,43,7,9,9,34,65,6,5,20]

# %%
plt.hist(data)
plt.show()

# %%
x = [4,5,6,7,8,9]
y = [1,2,3,4,3,23]
colour = ['red','yello','green','blue']
plt.scatter(x,y)
plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)

fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x,y,z)
ax.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 8
#       6 ax = fig.add_subplot(projection = '3d')
#       7 ax.scatter(x,y,z)
# ----> 8 ax.show()
#
# AttributeError: 'Axes3DSubplot' object has no attribute 'show'
